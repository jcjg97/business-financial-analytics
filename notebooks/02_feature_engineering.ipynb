# %% [markdown]
# # Feature Engineering for Financial Analytics
#
# This notebook demonstrates professional feature engineering and data preparation for a financial dataset. The goal is to create a clean, enriched dataset ready for machine learning and business intelligence (BI) applications.

# %% [markdown]
# ## 1. Load Dataset

# %%
import pandas as pd
import numpy as np

# Load the dataset
data_path = '../data/raw/financial_data.csv'
df = pd.read_csv(data_path)
df.head()
# Out:
#          date region    product  revenue  cost  units_sold
# 0  2022-01-01  North  Product A    12000  7000         300
# 1  2022-01-01  North  Product B     9500  5800         250
# 2  2022-01-01  North  Product C    13500  7600         320
# 3  2022-01-01  North  Product D    11000  6500         280
# 4  2022-01-01  North  Product E    14500  8200         340

# %% [markdown]
# ## 2. Convert Date Column to Datetime

# %%
# Convert 'date' column to datetime
df['date'] = pd.to_datetime(df['date'])
df.dtypes
# Out:
# date          datetime64[ns]
# region                object
# product               object
# revenue                int64
# cost                   int64
# units_sold             int64
# dtype: object

# %% [markdown]
# ## 3. Handle Missing Values

# %%
# Check for missing values
missing = df.isnull().sum()
print('Missing values per column:')
print(missing)

# Example: Fill missing numerical values with median, categorical with mode
for col in df.columns:
    if df[col].dtype in [np.float64, np.int64]:
        df[col] = df[col].fillna(df[col].median())
    elif df[col].dtype == 'object':
        df[col] = df[col].fillna(df[col].mode()[0])

# Verify no missing values remain
df.isnull().sum()
# Out:
# Missing values per column:
# date          0
# region        0
# product       0
# revenue       0
# cost          0
# units_sold    0
# dtype: int64
# date          0
# region        0
# product       0
# revenue       0
# cost          0
# units_sold    0
# dtype: int64

# %% [markdown]
# ## 4. Feature Engineering: Profit, Margin, Revenue per Unit

# %%
# Create new features
df['profit'] = df['revenue'] - df['cost']
df['margin'] = df['profit'] / df['revenue']
df['revenue_per_unit'] = df['revenue'] / df['units_sold']
df[['profit', 'margin', 'revenue_per_unit']].head()
# Out:
#    profit    margin  revenue_per_unit
# 0    5000  0.416667         40.000000
# 1    3700  0.389474         38.000000
# 2    5900  0.437037         42.187500
# 3    4500  0.409091         39.285714
# 4    6300  0.434483         42.647059

# %% [markdown]
# ## 5. Extract Time-Based Features

# %%
# Extract year and month
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df[['date', 'year', 'month']].head()
# Out:
#         date  year  month
# 0 2022-01-01  2022      1
# 1 2022-01-01  2022      1
# 2 2022-01-01  2022      1
# 3 2022-01-01  2022      1
# 4 2022-01-01  2022      1

# %% [markdown]
# ## 6. Encode Categorical Variables

# %%
# One-hot encode 'region' and 'product'
df = pd.get_dummies(df, columns=['region', 'product'], drop_first=True)
df.head()
# Out:
#         date  revenue  cost  units_sold  profit    margin  revenue_per_unit  \
# 0 2022-01-01    12000  7000         300    5000  0.416667         40.000000
# 1 2022-01-01     9500  5800         250    3700  0.389474         38.000000
# 2 2022-01-01    13500  7600         320    5900  0.437037         42.187500
# 3 2022-01-01    11000  6500         280    4500  0.409091         39.285714
# 4 2022-01-01    14500  8200         340    6300  0.434483         42.647059
#
#    year  month  region_North  region_South  region_West  product_Product B  \
# 0  2022      1          True         False        False              False
# 1  2022      1          True         False        False               True
# 2  2022      1          True         False        False              False
# 3  2022      1          True         False        False              False
# 4  2022      1          True         False        False              False
#
#    product_Product C  product_Product D  product_Product E
# 0              False              False              False
# 1              False              False              False
# 2               True              False              False
# 3              False               True              False
# 4              False              False               True

# %% [markdown]
# ## 7. Remove Duplicates

# %%
# Remove duplicate rows if any
before = df.shape[0]
df = df.drop_duplicates()
after = df.shape[0]
print(f'Removed {before - after} duplicate rows.')
# Out:
# Removed 0 duplicate rows.

# %% [markdown]
# ## 8. Prepare Final Cleaned Dataset

# %%
# Preview the cleaned dataset
df.head()

# Export to CSV
output_path = '../data/processed/financial_data_clean.csv'
df.to_csv(output_path, index=False)
print(f'Cleaned dataset saved to: {output_path}')
